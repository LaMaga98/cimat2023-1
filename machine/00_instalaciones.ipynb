# %% [markdown]
# Librerias:
#
#     * numpy
#     * scipy
#     * matplotlib
#     * scikit-learn
#     * scikit-image
#     * pandas
#     * sympy
#     * Tensorflow 2+
#     * Keras
#     * Pytorch

# %%
print("hola")
# Out:
# hola

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in ./.conda/lib/python3.11/site-packages (from opencv-python) (1.23.5)
# Downloading opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl (35.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.4/35.4 MB 995.5 kB/s eta 0:00:00:0100:010m
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install gdown
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/ely/Documents/Maestria/segundo_semestre/cimat2023-1/machine/.conda
#
#   added / updated specs:
#     - gdown
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     gdown-5.1.0                |     pyhd8ed1ab_0          21 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          21 KB
#
# The following NEW packages will be INSTALLED:
#
#   beautifulsoup4     pkgs/main/osx-arm64::beautifulsoup4-4.12.2-py311hca03da5_0
#   gdown              conda-forge/noarch::gdown-5.1.0-pyhd8ed1ab_0
#   soupsieve          pkgs/main/osx-arm64::soupsieve-2.5-py311hca03da5_0
#   tqdm               pkgs/main/osx-arm64::tqdm-4.65.0-py311hb6e6a13_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.12.12-hca03da5_0 --> 2024.3.11-hca03da5_0
#   certifi                        2023.11.17-py311hca03da5_0 --> 2024.2.2-py311hca03da5_0
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install pydrive
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/ely/Documents/Maestria/segundo_semestre/cimat2023-1/machine/.conda
#
#   added / updated specs:
#     - pydrive
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     google-api-core-2.10.1     |  py311hca03da5_0         148 KB
#     google-api-python-client-2.127.0|     pyhd8ed1ab_0         6.0 MB  conda-forge
#     google-auth-httplib2-0.2.0 |     pyhd8ed1ab_0          15 KB  conda-forge
#     googleapis-common-protos-1.56.4|  py311hca03da5_0         137 KB
#     httplib2-0.22.0            |     pyhd8ed1ab_0          93 KB  conda-forge
#     oauth2client-4.1.3         |             py_0          66 KB  conda-forge
#     pydrive-1.3.1              |             py_1          25 KB  conda-forge
#     uritemplate-4.1.1          |     pyhd8ed1ab_0          12 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         6.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   google-api-core    pkgs/main/osx-arm64::google-api-core-2.10.1-py311hca03da5_0
#   google-api-python~ conda-forge/noarch::google-api-python-client-2.127.0-pyhd8ed1ab_0
#   google-auth-httpl~ conda-forge/noarch::google-auth-httplib2-0.2.0-pyhd8ed1ab_0
#   googleapis-common~ pkgs/main/osx-arm64::googleapis-common-protos-1.56.4-py311hca03da5_0
#   httplib2           conda-forge/noarch::httplib2-0.22.0-pyhd8ed1ab_0
#   oauth2client       conda-forge/noarch::oauth2client-4.1.3-py_0
#   pydrive            conda-forge/noarch::pydrive-1.3.1-py_1
#   pyparsing          pkgs/main/osx-arm64::pyparsing-3.0.9-py311hca03da5_0
#   uritemplate        conda-forge/noarch::uritemplate-4.1.1-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
# google-api-python-cl | 6.0 MB    |                                       |   0%
# google-api-core-2.10 | 148 KB    |                                       |   0%
#
# googleapis-common-pr | 137 KB    |                                       |   0%
#
#
# httplib2-0.22.0      | 93 KB     |                                       |   0%
#
#
#
# oauth2client-4.1.3   | 66 KB     |                                       |   0%
#
#
#
#
# pydrive-1.3.1        | 25 KB     |                                       |   0%
#
#
#
#
#
# google-auth-httplib2 | 15 KB     |                                       |   0%
#
#
#
#
#
#
# uritemplate-4.1.1    | 12 KB     |                                       |   0%
#
# googleapis-common-pr | 137 KB    | ####3                                 |  12%
# google-api-python-cl | 6.0 MB    |                                       |   0%
#
#
#
# oauth2client-4.1.3   | 66 KB     | ########9                             |  24%
#
#
# httplib2-0.22.0      | 93 KB     | ######3                               |  17%
#
#
#
# oauth2client-4.1.3   | 66 KB     | ##################################### | 100%
# google-api-core-2.10 | 148 KB    | ##################################### | 100%
# google-api-core-2.10 | 148 KB    | ##################################### | 100%
#
#
# httplib2-0.22.0      | 93 KB     | ##################################### | 100%
#
# googleapis-common-pr | 137 KB    | ##################################### | 100%
#
# google-api-python-cl | 6.0 MB    | ###6                                  |  10%
#
#
#
#
#
#
# uritemplate-4.1.1    | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
# google-api-python-cl | 6.0 MB    | ############1                         |  33%
#
#
#
#
# pydrive-1.3.1        | 25 KB     | #######################9              |  65%
#
#
#
#
# google-api-python-cl | 6.0 MB    | #########################1            |  68%
#
#
#
#
#
# google-auth-httplib2 | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade certifi
# Out:
# Requirement already satisfied: certifi in ./.conda/lib/python3.11/site-packages (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install pydot
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/ely/Documents/Maestria/segundo_semestre/cimat2023-1/machine/.conda
#
#   added / updated specs:
#     - pydot
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boost-cpp-1.73.0           |      h1a28f6b_12          17 KB
#     cairo-1.16.0               |       h302bd0f_5         1.0 MB
#     expat-2.6.2                |       h313beb8_0         150 KB
#     font-ttf-dejavu-sans-mono-2.37|       hd3eb1b0_0         335 KB
#     font-ttf-inconsolata-2.001 |       hcb22688_0          83 KB
#     font-ttf-source-code-pro-2.030|       hd3eb1b0_0         654 KB
#     font-ttf-ubuntu-0.83       |       h8b1ccd4_0         1.5 MB
#     fontconfig-2.14.1          |       hee714a5_2         254 KB
#     fonts-anaconda-1           |       h8fa9717_0           3 KB
#     fonts-conda-ecosystem-1    |       hd3eb1b0_0           5 KB
#     fribidi-1.0.10             |       h1a28f6b_0          60 KB
#     gdk-pixbuf-2.42.10         |       h80987f9_0         581 KB
#     gettext-0.21.0             |       h13f89a0_1         3.1 MB
#     glib-2.78.4                |       h313beb8_0         507 KB
#     glib-tools-2.78.4          |       h313beb8_0         106 KB
#     graphite2-1.3.14           |       hc377ac9_1          75 KB
#     graphviz-2.50.0            |       hf331ead_1         2.4 MB
#     gts-0.7.6                  |       hde733a8_3         287 KB
#     harfbuzz-4.3.0             |       he9eebac_1         1.1 MB
#     libboost-1.73.0            |      h49e8a49_12        12.6 MB
#     libgd-2.3.3                |       h14f8a72_1         200 KB
#     libglib-2.78.4             |       h0a96307_0         2.7 MB
#     librsvg-2.54.4             |       hb3bd4c3_3         6.5 MB
#     libtool-2.4.6              |    h313beb8_1009         422 KB
#     libxml2-2.10.4             |       h372ba2a_0         638 KB
#     nspr-4.35                  |       h313beb8_0         243 KB
#     nss-3.89.1                 |       h313beb8_0         1.8 MB
#     pango-1.50.7               |       h7271ec9_0         402 KB
#     pixman-0.40.0              |       h1a28f6b_0         196 KB
#     poppler-22.12.0            |       h52f4003_3         1.6 MB
#     poppler-data-0.4.11        |       hca03da5_1         2.6 MB
#     pydot-1.4.2                |  py311hca03da5_0          56 KB
#     pyparsing-2.4.7            |     pyhd3eb1b0_0          59 KB
#     ------------------------------------------------------------
#                                            Total:        42.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   boost-cpp          pkgs/main/osx-arm64::boost-cpp-1.73.0-h1a28f6b_12
#   cairo              pkgs/main/osx-arm64::cairo-1.16.0-h302bd0f_5
#   expat              pkgs/main/osx-arm64::expat-2.6.2-h313beb8_0
#   font-ttf-dejavu-s~ pkgs/main/noarch::font-ttf-dejavu-sans-mono-2.37-hd3eb1b0_0
#   font-ttf-inconsol~ pkgs/main/noarch::font-ttf-inconsolata-2.001-hcb22688_0
#   font-ttf-source-c~ pkgs/main/noarch::font-ttf-source-code-pro-2.030-hd3eb1b0_0
#   font-ttf-ubuntu    pkgs/main/noarch::font-ttf-ubuntu-0.83-h8b1ccd4_0
#   fontconfig         pkgs/main/osx-arm64::fontconfig-2.14.1-hee714a5_2
#   fonts-anaconda     pkgs/main/noarch::fonts-anaconda-1-h8fa9717_0
#   fonts-conda-ecosy~ pkgs/main/noarch::fonts-conda-ecosystem-1-hd3eb1b0_0
#   fribidi            pkgs/main/osx-arm64::fribidi-1.0.10-h1a28f6b_0
#   gdk-pixbuf         pkgs/main/osx-arm64::gdk-pixbuf-2.42.10-h80987f9_0
#   gettext            pkgs/main/osx-arm64::gettext-0.21.0-h13f89a0_1
#   glib               pkgs/main/osx-arm64::glib-2.78.4-h313beb8_0
#   glib-tools         pkgs/main/osx-arm64::glib-tools-2.78.4-h313beb8_0
#   graphite2          pkgs/main/osx-arm64::graphite2-1.3.14-hc377ac9_1
#   graphviz           pkgs/main/osx-arm64::graphviz-2.50.0-hf331ead_1
#   gts                pkgs/main/osx-arm64::gts-0.7.6-hde733a8_3
#   harfbuzz           pkgs/main/osx-arm64::harfbuzz-4.3.0-he9eebac_1
#   libboost           pkgs/main/osx-arm64::libboost-1.73.0-h49e8a49_12
#   libgd              pkgs/main/osx-arm64::libgd-2.3.3-h14f8a72_1
#   libglib            pkgs/main/osx-arm64::libglib-2.78.4-h0a96307_0
#   libiconv           pkgs/main/osx-arm64::libiconv-1.16-h1a28f6b_2
#   librsvg            pkgs/main/osx-arm64::librsvg-2.54.4-hb3bd4c3_3
#   libtool            pkgs/main/osx-arm64::libtool-2.4.6-h313beb8_1009
#   libxml2            pkgs/main/osx-arm64::libxml2-2.10.4-h372ba2a_0
#   nspr               pkgs/main/osx-arm64::nspr-4.35-h313beb8_0
#   nss                pkgs/main/osx-arm64::nss-3.89.1-h313beb8_0
#   pango              pkgs/main/osx-arm64::pango-1.50.7-h7271ec9_0
#   pcre2              pkgs/main/osx-arm64::pcre2-10.42-hb066dcc_0
#   pixman             pkgs/main/osx-arm64::pixman-0.40.0-h1a28f6b_0
#   poppler            pkgs/main/osx-arm64::poppler-22.12.0-h52f4003_3
#   poppler-data       pkgs/main/osx-arm64::poppler-data-0.4.11-hca03da5_1
#   pydot              pkgs/main/osx-arm64::pydot-1.4.2-py311hca03da5_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   pyparsing          pkgs/main/osx-arm64::pyparsing-3.0.9-~ --> pkgs/main/noarch::pyparsing-2.4.7-pyhd3eb1b0_0
#
#
#
# Downloading and Extracting Packages:
# libboost-1.73.0      | 12.6 MB   |                                       |   0%
# librsvg-2.54.4       | 6.5 MB    |                                       |   0%
#
# gettext-0.21.0       | 3.1 MB    |                                       |   0%
#
#
# libglib-2.78.4       | 2.7 MB    |                                       |   0%
#
#
#
# poppler-data-0.4.11  | 2.6 MB    |                                       |   0%
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    |                                       |   0%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    |                                       |   0%
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    |                                       |   0%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.10.4       | 638 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 581 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.78.4          | 507 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtool-2.4.6        | 422 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 402 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 335 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 254 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nspr-4.35            | 243 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 200 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 196 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 12.6 MB   |                                       |   0% [A
#
# gettext-0.21.0       | 3.1 MB    | 1                                     |   1%
#
#
# libglib-2.78.4       | 2.7 MB    | 2                                     |   1%
# librsvg-2.54.4       | 6.5 MB    |                                       |   0%
#
#
#
# libboost-1.73.0      | 12.6 MB   | #6                                    |   4%
#
# gettext-0.21.0       | 3.1 MB    | ######1                               |  17%
# librsvg-2.54.4       | 6.5 MB    | ##9                                   |   8%
#
#
# libglib-2.78.4       | 2.7 MB    | #######1                              |  19%
#
#
#
# poppler-data-0.4.11  | 2.6 MB    | #####5                                |  15%
# librsvg-2.54.4       | 6.5 MB    | ########6                             |  23%
#
# gettext-0.21.0       | 3.1 MB    | ###################8                  |  54%
#
#
#
# libboost-1.73.0      | 12.6 MB   | #####3                                |  14%
#
#
# libglib-2.78.4       | 2.7 MB    | ####################4                 |  55%
#
#
# libglib-2.78.4       | 2.7 MB    | #########################1            |  68%
# librsvg-2.54.4       | 6.5 MB    | ###########                           |  30%
#
#
# libglib-2.78.4       | 2.7 MB    | ############################6         |  77%
#
#
#
# poppler-data-0.4.11  | 2.6 MB    | #####################                 |  57%
#
#
# libglib-2.78.4       | 2.7 MB    | ###############################8      |  86%
# librsvg-2.54.4       | 6.5 MB    | ############7                         |  34%
#
#
# libglib-2.78.4       | 2.7 MB    | ##################################8   |  94%
# librsvg-2.54.4       | 6.5 MB    | ##############2                       |  38%
#
#
#
# poppler-data-0.4.11  | 2.6 MB    | ########################1             |  65%
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | 2                                     |   1%
#
#
# libglib-2.78.4       | 2.7 MB    | ##################################### | 100%
# librsvg-2.54.4       | 6.5 MB    | ###############4                      |  42%
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | ###4                                  |   9%
#
#
#
# poppler-data-0.4.11  | 2.6 MB    | ##########################6           |  72%
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | #####3                                |  14%
#
#
#
# poppler-data-0.4.11  | 2.6 MB    | ############################8         |  78%
# librsvg-2.54.4       | 6.5 MB    | ################5                     |  45%
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | #########9                            |  27%
#
#
#
# poppler-data-0.4.11  | 2.6 MB    | ##############################6       |  83%
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | ##############3                       |  39%
# librsvg-2.54.4       | 6.5 MB    | #################4                    |  47%
#
#
#
# poppler-data-0.4.11  | 2.6 MB    | ################################2     |  87%
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | #################2                    |  47%
# librsvg-2.54.4       | 6.5 MB    | ##################2                   |  49%
#
#
#
# poppler-data-0.4.11  | 2.6 MB    | ##################################    |  92%
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | ####################6                 |  56%
# librsvg-2.54.4       | 6.5 MB    | ###################2                  |  52%
#
#
#
# poppler-data-0.4.11  | 2.6 MB    | ###################################5  |  96%
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | #######################5              |  64%
# librsvg-2.54.4       | 6.5 MB    | ###################9                  |  54%
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | ###########################2          |  74%
#
#
#
# poppler-data-0.4.11  | 2.6 MB    | ##################################### | 100%
# librsvg-2.54.4       | 6.5 MB    | #####################                 |  57%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | 3                                     |   1%
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | ##############################1       |  82%
#
#
#
# poppler-data-0.4.11  | 2.6 MB    | ##################################### | 100%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | #2                                    |   3%
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | #################################     |  89%
# librsvg-2.54.4       | 6.5 MB    | #####################8                |  59%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##5                                   |   7%
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | ###################################7  |  97%
# librsvg-2.54.4       | 6.5 MB    | ######################5               |  61%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | #####3                                |  14%
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | 3                                     |   1%
# librsvg-2.54.4       | 6.5 MB    | #######################5              |  64%
#
#
#
#
# libboost-1.73.0      | 12.6 MB   | ######5                               |  18%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | #######2                              |  20%
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##9                                   |   8%
# librsvg-2.54.4       | 6.5 MB    | ########################3             |  66%
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #####5                                |  15%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ########7                             |  24%
# librsvg-2.54.4       | 6.5 MB    | #########################             |  68%
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###########8                          |  32%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##########6                           |  29%
# librsvg-2.54.4       | 6.5 MB    | #########################8            |  70%
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###############5                      |  42%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ############8                         |  35%
# librsvg-2.54.4       | 6.5 MB    | ##########################5           |  72%
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##################8                   |  51%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##############4                       |  39%
# librsvg-2.54.4       | 6.5 MB    | ###########################2          |  74%
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #######################6              |  64%
# librsvg-2.54.4       | 6.5 MB    | ############################          |  76%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ################3                     |  44%
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###########################3          |  74%
# librsvg-2.54.4       | 6.5 MB    | ############################7         |  78%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##################5                   |  50%
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ################################9     |  89%
# librsvg-2.54.4       | 6.5 MB    | #############################5        |  80%
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ####################################9 | 100%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ####################                  |  54%
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##################################### | 100%
# librsvg-2.54.4       | 6.5 MB    | ##############################7       |  83%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | 3                                     |   1%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ######################2               |  60%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##7                                   |   7%
# librsvg-2.54.4       | 6.5 MB    | ###############################6      |  86%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ####6                                 |  13%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | #######################8              |  64%
# librsvg-2.54.4       | 6.5 MB    | ################################5     |  88%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########1                             |  22%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | #########################4            |  69%
# librsvg-2.54.4       | 6.5 MB    | #################################4    |  90%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #############1                        |  36%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##########################9           |  73%
# librsvg-2.54.4       | 6.5 MB    | ##################################5   |  93%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ################2                     |  44%
# librsvg-2.54.4       | 6.5 MB    | ###################################4  |  96%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | #############################1        |  79%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ###################3                  |  52%
# libboost-1.73.0      | 12.6 MB   | #######4                              |  20%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##############################7       |  83%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ######################4               |  61%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ################################9     |  89%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | 5                                     |   1%
# librsvg-2.54.4       | 6.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #########################9            |  70%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##################################8   |  94%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | #####7                                |  16%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #############################         |  78%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | ########9                             |  24%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ####################################7 |  99%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ################################1     |  87%
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 12.6 MB   | #######9                              |  22%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | ################3                     |  44%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ###################################2  |  95%
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ###3                                  |   9%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | #####################                 |  57%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | #########                             |  24%
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | 9                                     |   2%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | ##########################3           |  71%
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ############4                         |  34%
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ########1                             |  22%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | ###############################5      |  85%
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ############6                         |  34%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 12.6 MB   | ########3                             |  23%
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ####################8                 |  56%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ##########################            |  70%
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 12.6 MB   | ########6                             |  23%
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.10.4       | 638 KB    | 9                                     |   3%
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ###########################1          |  73%
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ###############################1      |  84%
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.10.4       | 638 KB    | #######4                              |  20%
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 12.6 MB   | #########                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 581 KB    | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.78.4          | 507 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.10.4       | 638 KB    | #########################9            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 581 KB    | ########1                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.78.4          | 507 KB    | #####8                                |  16%
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.10.4       | 638 KB    | ################################4     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 581 KB    | #################3                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.78.4          | 507 KB    | ##############                        |  38%
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.10.4       | 638 KB    | ##################################### | 100%
#
# libboost-1.73.0      | 12.6 MB   | #########2                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 581 KB    | ###################################6  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtool-2.4.6        | 422 KB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.78.4          | 507 KB    | #########################6            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 581 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 402 KB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.78.4          | 507 KB    | ################################6     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 12.6 MB   | #########6                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 402 KB    | #######3                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.78.4          | 507 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 402 KB    | ##########################4           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 335 KB    | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 12.6 MB   | #########8                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 402 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtool-2.4.6        | 422 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    | ##                                    |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 254 KB    | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 335 KB    | #####################2                |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 12.6 MB   | ##########1                           |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 254 KB    | ####################9                 |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 335 KB    | #################################5    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 335 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 254 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nspr-4.35            | 243 KB    | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 12.6 MB   | ##########2                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 196 KB    | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nspr-4.35            | 243 KB    | ###############################6      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 200 KB    | ####################7                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 12.6 MB   | ##########4                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 200 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 196 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nspr-4.35            | 243 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 12.6 MB   | ###############9                      |  43% [A
#
# libboost-1.73.0      | 12.6 MB   | ###########################4          |  74%
#
# libboost-1.73.0      | 12.6 MB   | ################################7     |  89%
#
# libboost-1.73.0      | 12.6 MB   | ##################################7   |  94%
#
# gettext-0.21.0       | 3.1 MB    | #################################7    |  91%
#
# gettext-0.21.0       | 3.1 MB    | ##################################8   |  94%
#
# gettext-0.21.0       | 3.1 MB    | ####################################1 |  98%
#
# libboost-1.73.0      | 12.6 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install tensorflow-gpu
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - tensorflow-gpu
#
# Current channels:
#
#   - defaults
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://conda.anaconda.org/conda-forge/osx-arm64
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow-macos
# Out:
# Collecting tensorflow-macos
#   Downloading tensorflow_macos-2.16.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (3.5 kB)
# Collecting tensorflow==2.16.1 (from tensorflow-macos)
#   Downloading tensorflow-2.16.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in ./.conda/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.conda/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (1.6.3)
# Collecting flatbuffers>=23.5.26 (from tensorflow==2.16.1->tensorflow-macos)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.conda/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.conda/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (0.2.0)
# Collecting h5py>=3.10.0 (from tensorflow==2.16.1->tensorflow-macos)
#   Downloading h5py-3.11.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow==2.16.1->tensorflow-macos)
#   Downloading libclang-18.1.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting ml-dtypes~=0.3.1 (from tensorflow==2.16.1->tensorflow-macos)
#   Downloading ml_dtypes-0.3.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.conda/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (3.3.0)
# Requirement already satisfied: packaging in ./.conda/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.conda/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in ./.conda/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (2.31.0)
# Requirement already satisfied: setuptools in ./.conda/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in ./.conda/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.conda/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.conda/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./.conda/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.conda/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (1.48.2)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow==2.16.1->tensorflow-macos)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.0.0 (from tensorflow==2.16.1->tensorflow-macos)
#   Downloading keras-3.3.3-py3-none-any.whl.metadata (5.7 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow==2.16.1->tensorflow-macos)
#   Downloading tensorflow_io_gcs_filesystem-0.36.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in ./.conda/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (1.23.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./.conda/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow==2.16.1->tensorflow-macos) (0.35.1)
# Collecting rich (from keras>=3.0.0->tensorflow==2.16.1->tensorflow-macos)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.0.0->tensorflow==2.16.1->tensorflow-macos)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.0.0->tensorflow==2.16.1->tensorflow-macos)
#   Downloading optree-0.11.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 920.6 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1->tensorflow-macos) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1->tensorflow-macos) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1->tensorflow-macos) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1->tensorflow-macos) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in ./.conda/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1->tensorflow-macos) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.conda/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1->tensorflow-macos) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.conda/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1->tensorflow-macos) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.1->tensorflow-macos) (2.1.3)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.0.0->tensorflow==2.16.1->tensorflow-macos)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.conda/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.1->tensorflow-macos) (2.17.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.1->tensorflow-macos)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow_macos-2.16.1-cp311-cp311-macosx_12_0_arm64.whl (2.2 kB)
# Downloading tensorflow-2.16.1-cp311-cp311-macosx_12_0_arm64.whl (227.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.0/227.0 MB 4.1 MB/s eta 0:00:0000:0100:02
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading h5py-3.11.0-cp311-cp311-macosx_11_0_arm64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 5.8 MB/s eta 0:00:0000:0100:01
# Downloading keras-3.3.3-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 6.0 MB/s eta 0:00:00a 0:00:01
# Downloading libclang-18.1.1-py2.py3-none-macosx_11_0_arm64.whl (26.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.4/26.4 MB 2.3 MB/s eta 0:00:0000:0100:01
# Downloading ml_dtypes-0.3.2-cp311-cp311-macosx_10_9_universal2.whl (389 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.8/389.8 kB 2.5 MB/s eta 0:00:00a 0:00:01
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 2.7 MB/s eta 0:00:0000:0100:01
# Downloading tensorflow_io_gcs_filesystem-0.36.0-cp311-cp311-macosx_12_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 3.1 MB/s eta 0:00:0000:0100:01
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.11.0-cp311-cp311-macosx_11_0_arm64.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 3.3 MB/s eta 0:00:00a 0:00:01
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 3.3 MB/s eta 0:00:00a 0:00:01
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 3.5 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, tensorflow-io-gcs-filesystem, optree, ml-dtypes, mdurl, h5py, tensorboard, markdown-it-py, rich, keras, tensorflow, tensorflow-macos
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.1
#     Uninstalling tensorboard-2.12.1:
#       Successfully uninstalled tensorboard-2.12.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# Successfully installed flatbuffers-24.3.25 h5py-3.11.0 keras-3.3.3 libclang-18.1.1 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.3.2 namex-0.0.8 optree-0.11.0 rich-13.7.1 tensorboard-2.16.2 tensorflow-2.16.1 tensorflow-io-gcs-filesystem-0.36.0 tensorflow-macos-2.16.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow-metal
# Out:
# Collecting tensorflow-metal
#   Downloading tensorflow_metal-1.1.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (1.2 kB)
# Requirement already satisfied: wheel~=0.35 in ./.conda/lib/python3.11/site-packages (from tensorflow-metal) (0.35.1)
# Requirement already satisfied: six>=1.15.0 in ./.conda/lib/python3.11/site-packages (from tensorflow-metal) (1.16.0)
# Downloading tensorflow_metal-1.1.0-cp311-cp311-macosx_12_0_arm64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 4.1 MB/s eta 0:00:0000:0100:010m
# Installing collected packages: tensorflow-metal
# Successfully installed tensorflow-metal-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c apple tensorflow-deps
# Out:
# Channels:
#  - apple
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# failed
#
# LibMambaUnsatisfiableError: Encountered problems while solving:
#   - package tensorflow-deps-2.9.0-0 requires h5py >=3.6.0,<3.7, but none of the providers can be installed
#
# Could not solve for environment specs
# The following packages are incompatible
# ├─ pin-1 is installable and it requires
# │  └─ python 3.11.* , which can be installed;
# └─ tensorflow-deps is not installable because there are no viable options
#    ├─ tensorflow-deps [2.5.0|2.6.0|2.7.0] would require
#    │  └─ h5py >=3.1.0,<3.2  but there are no viable options
#    │     ├─ h5py [3.1.0|3.6.0] would require
#    │     │  └─ python >=3.8,<3.9.0a0 , which conflicts with any installable versions previously reported;
#    │     └─ h5py [3.1.0|3.6.0] would require
#    │        └─ python >=3.9,<3.10.0a0 , which conflicts with any installable versions previously reported;
#    ├─ tensorflow-deps [2.8.0|2.9.0] would require
#    │  ├─ h5py >=3.6.0,<3.7  but there are no viable options
#    │  │  ├─ h5py 3.6.0 would require
#    │  │  │  └─ python >=3.10,<3.11.0a0 , which conflicts with any installable versions previously reported;
#    │  │  ├─ h5py [3.1.0|3.6.0], which cannot be installed (as previously explained);
#    │  │  ├─ h5py [3.1.0|3.6.0], which cannot be installed (as previously explained);
#    │  │  ├─ h5py 3.6.0 would require
#    │  │  │  └─ python >=3.10,<3.11.0a0 *_cpython, which conflicts with any installable versions previously reported;
#    │  │  ├─ h5py 3.6.0 would require
#    │  │  │  └─ python >=3.8,<3.9.0a0 *_cpython, which conflicts with any installable versions previously reported;
#    │  │  └─ h5py 3.6.0 would require
#    │  │     └─ python >=3.9,<3.10.0a0 *_cpython, which conflicts with any installable versions previously reported;
#    │  └─ numpy >=1.21.2,<1.22  but there are no viable options
#    │     ├─ numpy [1.21.2|1.21.5|1.21.6] would require
#    │     │  └─ python >=3.10,<3.11.0a0 , which conflicts with any installable versions previously reported;
#    │     ├─ numpy [1.21.2|1.21.3|1.21.5|1.21.6] would require
#    │     │  └─ python >=3.8,<3.9.0a0 , which conflicts with any installable versions previously reported;
#    │     ├─ numpy [1.21.2|1.21.3|1.21.5|1.21.6] would require
#    │     │  └─ python >=3.9,<3.10.0a0 , which conflicts with any installable versions previously reported;
#    │     ├─ numpy [1.21.3|1.21.4|1.21.5|1.21.6|1.23.2] would require
#    │     │  └─ python >=3.10,<3.11.0a0 *_cpython, which conflicts with any installable versions previously reported;
#    │     ├─ numpy [1.21.3|1.21.4|1.21.5|1.21.6|1.23.2] would require
#    │     │  └─ python >=3.8,<3.9.0a0 *_cpython, which conflicts with any installable versions previously reported;
#    │     └─ numpy [1.21.3|1.21.4|1.21.5|1.21.6|1.23.2] would require
#    │        └─ python >=3.9,<3.10.0a0 *_cpython, which conflicts with any installable versions previously reported;
#    └─ tensorflow-deps 2.10.0 would require
#       └─ numpy >=1.23.2,<1.23.3 , which cannot be installed (as previously explained).
#
# Pins seem to be involved in the conflict. Currently pinned specs:
#  - python 3.11.* (labeled as 'pin-1')
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys

import tensorflow.keras
import pandas as pd
import sklearn as sk
import scipy as sp
import tensorflow as tf
import platform

print(f"Python Platform: {platform.platform()}")
print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
print(f"SciPy {sp.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: macOS-14.4.1-arm64-arm-64bit
# Tensor Flow Version: 2.16.1
# Keras Version: 3.3.3
#
# Python 3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]
# Pandas 2.1.4
# Scikit-Learn 1.3.0
# SciPy 1.11.4
# GPU is available

# %%
pip install certifi
# Out:
# Requirement already satisfied: certifi in ./.conda/lib/python3.11/site-packages (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
